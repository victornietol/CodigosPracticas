# %%
import pandas as pd
import numpy as np

# %%
numeros = pd.Series([1,2,3,4,5])
numeros
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
numeros = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
numeros
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
datos = {'a':1, 'b':2, 'c':3}
serie_dict = pd.Series(datos)
serie_dict
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
numeros['c']
# Out:
# 3

# %%
numeros['a'] = 10
numeros
# Out:
# a    10
# b     2
# c     3
# d     4
# e     5
# dtype: int64

# %%
cuadrados = numeros**2
cuadrados
# Out:
# a    100
# b      4
# c      9
# d     16
# e     25
# dtype: int64

# %%
numeros + 3
# Out:
# a    13
# b     5
# c     6
# d     7
# e     8
# dtype: int64

# %%
numeros
# Out:
# a    10
# b     2
# c     3
# d     4
# e     5
# dtype: int64

# %%
numeros.mean()
# Out:
# 4.8

# %%
numeros.sum()
# Out:
# 24

# %%
numeros.max()
# Out:
# 10

# %%
numeros.min()
# Out:
# 2

# %%
numeros[numeros > 3]
# Out:
# a    10
# d     4
# e     5
# dtype: int64

# %%
numeros.apply(np.log)
# Out:
# a    2.302585
# b    0.693147
# c    1.098612
# d    1.386294
# e    1.609438
# dtype: float64

# %%
nombres = pd.Series(['ana', 'luis', 'pedro'])
edades = pd.Series([25,30,35])
df_personas = pd.DataFrame({'Nombre': nombres, 'Edades': edades})
df_personas
# Out:
#   Nombre  Edades
# 0    ana      25
# 1   luis      30
# 2  pedro      35
