# %%
import pandas as pd

# %%
data = [
    {'Nombre': 'Ana', 'Edad':25, 'Ciudad':'Madrid'},
    {'Nombre': 'Luis', 'Edad':30, 'Ciudad':'Barcelona'},
    {'Nombre': 'Pedro', 'Edad':22, 'Ciudad':'Valencia'}
]

df = pd.DataFrame(data)
df
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana    25     Madrid
# 1   Luis    30  Barcelona
# 2  Pedro    22   Valencia

# %%
data = {
    'Nombre': ['Ana', 'Luis', 'Pedro','Ana'],
    'Edad': [25,30,22,29],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia','Sevilla']
}
df = pd.DataFrame(data)
df
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana    25     Madrid
# 1   Luis    30  Barcelona
# 2  Pedro    22   Valencia
# 3    Ana    29    Sevilla

# %%
nombres = df['Nombre']
nombres
# Out:
# 0      Ana
# 1     Luis
# 2    Pedro
# 3      Ana
# Name: Nombre, dtype: object

# %%
df['Salario'] = [30000,40000,25000,32000]
df
# Out:
#   Nombre  Edad     Ciudad  Salario
# 0    Ana    25     Madrid    30000
# 1   Luis    30  Barcelona    40000
# 2  Pedro    22   Valencia    25000
# 3    Ana    29    Sevilla    32000

# %%
df.drop('Salario', axis=1, inplace=True)
df
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana    25     Madrid
# 1   Luis    30  Barcelona
# 2  Pedro    22   Valencia
# 3    Ana    29    Sevilla

# %%
primera_fila = df.iloc[0]
print(primera_fila, end="\n-------------------------\n")
tercera_fila = df.iloc[2]
print(tercera_fila)
# Out:
# Nombre       Ana
# Edad          25
# Ciudad    Madrid
# Name: 0, dtype: object
# -------------------------
# Nombre       Pedro
# Edad            22
# Ciudad    Valencia
# Name: 2, dtype: object

# %%
df.loc[df['Nombre']=='Ana']
# Out:
#   Nombre  Edad   Ciudad
# 0    Ana    25   Madrid
# 3    Ana    29  Sevilla

# %%
df.loc[df['Edad'] < 30]
# Out:
#   Nombre  Edad    Ciudad
# 0    Ana    25    Madrid
# 2  Pedro    22  Valencia
# 3    Ana    29   Sevilla

# %%
df.sort_values(by='Edad', ascending=False)
# Out:
#   Nombre  Edad     Ciudad
# 1   Luis    30  Barcelona
# 3    Ana    29    Sevilla
# 0    Ana    25     Madrid
# 2  Pedro    22   Valencia

# %%
df['Edad'].mean()
# Out:
# 26.5

# %%
df['Edad'].max()
# Out:
# 30

# %%
data_w_None = {
    'Nombre': ['Ana', 'Luis', 'Pedro','Ana'],
    'Edad': [25,30,None,29],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia',None]
}
df_none = pd.DataFrame(data_w_None)
df_none
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana  25.0     Madrid
# 1   Luis  30.0  Barcelona
# 2  Pedro   NaN   Valencia
# 3    Ana  29.0       None

# %%
df_without_none = df_none.dropna()
df_without_none
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana  25.0     Madrid
# 1   Luis  30.0  Barcelona

# %%
df_none.fillna(value={'Edad':20, 'Ciudad':'Lima'})
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana  25.0     Madrid
# 1   Luis  30.0  Barcelona
# 2  Pedro  20.0   Valencia
# 3    Ana  29.0       Lima
